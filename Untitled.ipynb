# %% [markdown]
# # Highly divisible triangular number
#
# ## Problem 12
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
# 1: 1
#
# 3: 1,3
#
# 6: 1,2,3,6
#
# 10: 1,2,5,10
#
# 15: 1,3,5,15
#
# 21: 1,3,7,21
#
# 28: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
def triangle_maker(num):
    sum_num = 0
    for i in range(num):
        sum_num += i+1
    return sum_num

# %%
triangle_maker(7)
# Out:
# 28

# %%
def divisor_maker(num):
    divisor_list = []
    i = 1
    while i <= num:
        if num % i == 0:
            #print(i)
            divisor_list.append(i)
        i += 1
    return divisor_list

# %%
i=1
while len(some_list) < 200:
    some_list = divisor_maker(triangle_maker(i))
    if len(some_list) >= 200:
        print(i)
        break
    else:
        i +=1

len(some_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-b66eff61219f> in <module>
#       1 i=1
#       2 while len(some_list) < 200:
# ----> 3     some_list = divisor_maker(triangle_maker(i))
#       4     if len(some_list) >= 200:
#       5         print(i)
#
# <ipython-input-24-78467fbed2e2> in divisor_maker(num)
#       3     i = 1
#       4     while i <= num:
# ----> 5         if num % i == 0:
#       6             #print(i)
#       7             divisor_list.append(i)
#
# KeyboardInterrupt:
